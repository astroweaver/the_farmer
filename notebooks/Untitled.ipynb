# %%
# In order to make Farmer v3, we need to understand how to resample binary segementations to approximate in other bands with different resolutions.

# Grab segementation image
segmap = fits.open('/Users/jweaver/Projects/Current/Farmer_GalSim/data/intermediate/interim/old/B1_SEGMAPS.fits')
fig, ax = plt.subplots(figsize=(10,10))
ax.imshow(segmap[1].data)

# %%
import scipy.ndimage
zseg = scipy.ndimage.zoom(segmap[1].data, 0.15/0.6, order=0)
fig, ax = plt.subplots(figsize=(10,10))
ax.imshow(zseg)

# %%
len(np.unique(zseg)) / len(np.unique(segmap[1].data))
# Out:
# 0.9977315689981097
